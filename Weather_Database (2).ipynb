# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
import pandas as pd
import matplotlib.pyplot as plt
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
#Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6a600d7687223bc277a2dc621cb9153a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mindelo
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | harqalah
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | sao jose da coroa grande
# Processing Record 13 of Set 1 | sao joao da barra
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | natal
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | kisangani
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | charters towers
# Processing Record 24 of Set 1 | sosva
# Processing Record 25 of Set 1 | baruun-urt
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | mehamn
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | beira
# Processing Record 32 of Set 1 | atagay
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | comodoro rivadavia
# Processing Record 41 of Set 1 | mongoumba
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | aqtobe
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | pochutla
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | san cristobal
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | saint-louis
# Processing Record 5 of Set 2 | sorland
# Processing Record 6 of Set 2 | huarmey
# Processing Record 7 of Set 2 | burnie
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | prince rupert
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | broken hill
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | vila velha
# Processing Record 16 of Set 2 | bima
# Processing Record 17 of Set 2 | rubtsovsk
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | wajima
# Processing Record 21 of Set 2 | berbera
# Processing Record 22 of Set 2 | lillooet
# Processing Record 23 of Set 2 | hofn
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | sirnak
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | santa rosa
# Processing Record 30 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 2 | verkhoyansk
# Processing Record 32 of Set 2 | padang
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | la peca
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | horta
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | portland
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | genhe
# Processing Record 46 of Set 2 | hambantota
# Processing Record 47 of Set 2 | witu
# Processing Record 48 of Set 2 | klyuchi
# Processing Record 49 of Set 2 | mitu
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | farrukhnagar
# Processing Record 3 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 3 | puerto escondido
# Processing Record 5 of Set 3 | mashhad
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | suntar
# Processing Record 8 of Set 3 | suluq
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | barabai
# Processing Record 12 of Set 3 | bratsk
# Processing Record 13 of Set 3 | salinopolis
# Processing Record 14 of Set 3 | guerrero negro
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | izmit
# Processing Record 17 of Set 3 | quatre cocos
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | oistins
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | kahului
# Processing Record 23 of Set 3 | marzuq
# Processing Record 24 of Set 3 | cururupu
# Processing Record 25 of Set 3 | gilazi
# City not found. Skipping...
# Processing Record 26 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | maniitsoq
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 3 | byron bay
# Processing Record 33 of Set 3 | shillong
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | araouane
# Processing Record 36 of Set 3 | nelson bay
# Processing Record 37 of Set 3 | cavnic
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | guayaramerin
# Processing Record 40 of Set 3 | ossora
# Processing Record 41 of Set 3 | nagapattinam
# Processing Record 42 of Set 3 | biak
# Processing Record 43 of Set 3 | giyani
# Processing Record 44 of Set 3 | malkangiri
# Processing Record 45 of Set 3 | okha
# Processing Record 46 of Set 3 | kutoarjo
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | buraydah
# Processing Record 49 of Set 3 | diego de almagro
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | yithion
# City not found. Skipping...
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | edremit
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | saint-marc-des-carrieres
# Processing Record 10 of Set 4 | rodez
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | vaini
# Processing Record 13 of Set 4 | aripuana
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | havre-saint-pierre
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | waitati
# Processing Record 18 of Set 4 | san jose
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | warrington
# Processing Record 21 of Set 4 | barabinsk
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | noumea
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | mount pleasant
# Processing Record 28 of Set 4 | verkhnevilyuysk
# Processing Record 29 of Set 4 | najran
# Processing Record 30 of Set 4 | saint-michel-des-saints
# Processing Record 31 of Set 4 | peace river
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | batagay-alyta
# Processing Record 34 of Set 4 | poronaysk
# Processing Record 35 of Set 4 | bolshaya sosnova
# Processing Record 36 of Set 4 | coahuayana
# Processing Record 37 of Set 4 | rocky mountain house
# Processing Record 38 of Set 4 | qaanaaq
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | tello
# Processing Record 41 of Set 4 | atasu
# Processing Record 42 of Set 4 | allanmyo
# City not found. Skipping...
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | wade hampton
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | sidney
# Processing Record 47 of Set 4 | axim
# Processing Record 48 of Set 4 | mwense
# Processing Record 49 of Set 4 | hastings
# Processing Record 50 of Set 4 | te anau
# Processing Record 1 of Set 5 | ornskoldsvik
# Processing Record 2 of Set 5 | lusambo
# Processing Record 3 of Set 5 | ambilobe
# Processing Record 4 of Set 5 | zhigansk
# Processing Record 5 of Set 5 | minab
# Processing Record 6 of Set 5 | honningsvag
# Processing Record 7 of Set 5 | gaya
# Processing Record 8 of Set 5 | soure
# Processing Record 9 of Set 5 | cap malheureux
# Processing Record 10 of Set 5 | cesis
# Processing Record 11 of Set 5 | umba
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | jiwani
# Processing Record 14 of Set 5 | palaikastron
# Processing Record 15 of Set 5 | mecca
# Processing Record 16 of Set 5 | seoul
# Processing Record 17 of Set 5 | yeniseysk
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | parit buntar
# Processing Record 20 of Set 5 | nadym
# Processing Record 21 of Set 5 | kandi
# Processing Record 22 of Set 5 | bejar
# Processing Record 23 of Set 5 | gradignan
# Processing Record 24 of Set 5 | beyneu
# Processing Record 25 of Set 5 | dakar
# Processing Record 26 of Set 5 | babanka
# Processing Record 27 of Set 5 | george town
# Processing Record 28 of Set 5 | pitman
# Processing Record 29 of Set 5 | santa helena de goias
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | irece
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | saint-philippe
# Processing Record 34 of Set 5 | plettenberg bay
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | freeport
# Processing Record 37 of Set 5 | moranbah
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | flinders
# Processing Record 40 of Set 5 | rocha
# Processing Record 41 of Set 5 | hermanus
# Processing Record 42 of Set 5 | beloha
# Processing Record 43 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 5 | intipuca
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | bubaque
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | laguna
# Processing Record 49 of Set 5 | merauke
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | dzhebariki-khaya
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | cassilandia
# Processing Record 4 of Set 6 | itarema
# Processing Record 5 of Set 6 | derzhavinsk
# Processing Record 6 of Set 6 | joshimath
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | zhuhai
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | kasongo-lunda
# Processing Record 11 of Set 6 | vitoria
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | dolni bousov
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 6 | port-gentil
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | paso de carrasco
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | deputatskiy
# Processing Record 21 of Set 6 | oussouye
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | asfi
# Processing Record 25 of Set 6 | la romana
# Processing Record 26 of Set 6 | thompson
# Processing Record 27 of Set 6 | hengshui
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | carbonia
# Processing Record 30 of Set 6 | graham
# Processing Record 31 of Set 6 | wyndham
# Processing Record 32 of Set 6 | puqi
# Processing Record 33 of Set 6 | soyo
# Processing Record 34 of Set 6 | marsabit
# Processing Record 35 of Set 6 | shurugwi
# Processing Record 36 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 6 | barra patuca
# Processing Record 38 of Set 6 | namie
# Processing Record 39 of Set 6 | shache
# Processing Record 40 of Set 6 | kulhudhuffushi
# Processing Record 41 of Set 6 | ramhormoz
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | tasiilaq
# Processing Record 44 of Set 6 | carballo
# Processing Record 45 of Set 6 | elk plain
# Processing Record 46 of Set 6 | benghazi
# Processing Record 47 of Set 6 | samarai
# Processing Record 48 of Set 6 | forestville
# Processing Record 49 of Set 6 | bambous virieux
# Processing Record 50 of Set 6 | vagur
# Processing Record 1 of Set 7 | meybod
# Processing Record 2 of Set 7 | bairiki
# Processing Record 3 of Set 7 | esso
# Processing Record 4 of Set 7 | burica
# City not found. Skipping...
# Processing Record 5 of Set 7 | varna
# Processing Record 6 of Set 7 | jumla
# Processing Record 7 of Set 7 | vila franca do campo
# Processing Record 8 of Set 7 | daltenganj
# Processing Record 9 of Set 7 | tam ky
# Processing Record 10 of Set 7 | provideniya
# Processing Record 11 of Set 7 | pahrump
# Processing Record 12 of Set 7 | cayambe
# Processing Record 13 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | yumen
# Processing Record 15 of Set 7 | atambua
# Processing Record 16 of Set 7 | nautla
# Processing Record 17 of Set 7 | karratha
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | bentiu
# Processing Record 20 of Set 7 | xuddur
# Processing Record 21 of Set 7 | vila do maio
# Processing Record 22 of Set 7 | kaeo
# Processing Record 23 of Set 7 | bereda
# Processing Record 24 of Set 7 | launceston
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | el dorado
# Processing Record 28 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 7 | pauini
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | fukue
# Processing Record 32 of Set 7 | colares
# Processing Record 33 of Set 7 | north bend
# Processing Record 34 of Set 7 | huckeswagen
# Processing Record 35 of Set 7 | sebezh
# Processing Record 36 of Set 7 | kentau
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | lebu
# Processing Record 39 of Set 7 | rock sound
# Processing Record 40 of Set 7 | college
# Processing Record 41 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | san quintin
# Processing Record 43 of Set 7 | hanover
# Processing Record 44 of Set 7 | aitape
# Processing Record 45 of Set 7 | zeerust
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | vitim
# Processing Record 48 of Set 7 | tabuk
# Processing Record 49 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 7 | denpasar
# Processing Record 1 of Set 8 | corrales
# Processing Record 2 of Set 8 | parati
# Processing Record 3 of Set 8 | kungurtug
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | diapaga
# Processing Record 6 of Set 8 | waipawa
# Processing Record 7 of Set 8 | limoncito
# Processing Record 8 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 9 of Set 8 | turukhansk
# Processing Record 10 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 8 | jacareacanga
# Processing Record 12 of Set 8 | tarbes
# Processing Record 13 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 8 | vieira de leiria
# Processing Record 15 of Set 8 | puerto cabello
# Processing Record 16 of Set 8 | mulege
# Processing Record 17 of Set 8 | ribeira brava
# Processing Record 18 of Set 8 | ticleni
# Processing Record 19 of Set 8 | surt
# Processing Record 20 of Set 8 | linshu
# City not found. Skipping...
# Processing Record 21 of Set 8 | wanxian
# Processing Record 22 of Set 8 | phan thiet
# Processing Record 23 of Set 8 | geraldton
# Processing Record 24 of Set 8 | chicama
# Processing Record 25 of Set 8 | lagos
# Processing Record 26 of Set 8 | phangnga
# Processing Record 27 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 8 | beian
# Processing Record 29 of Set 8 | constitucion
# Processing Record 30 of Set 8 | shenjiamen
# Processing Record 31 of Set 8 | valkeakoski
# Processing Record 32 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 8 | georgiyevka
# Processing Record 34 of Set 8 | horb
# Processing Record 35 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 8 | los llanos de aridane
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | saint anthony
# Processing Record 39 of Set 8 | lensk
# Processing Record 40 of Set 8 | idlib
# Processing Record 41 of Set 8 | asau
# Processing Record 42 of Set 8 | sivas
# Processing Record 43 of Set 8 | namibe
# Processing Record 44 of Set 8 | malumfashi
# Processing Record 45 of Set 8 | takoradi
# Processing Record 46 of Set 8 | niteroi
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | falun
# Processing Record 49 of Set 8 | skjervoy
# Processing Record 50 of Set 8 | tautira
# Processing Record 1 of Set 9 | potiskum
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | gazanjyk
# Processing Record 4 of Set 9 | shahrud
# Processing Record 5 of Set 9 | mbeya
# Processing Record 6 of Set 9 | pangnirtung
# Processing Record 7 of Set 9 | iquique
# Processing Record 8 of Set 9 | lakes entrance
# Processing Record 9 of Set 9 | san carlos de bariloche
# Processing Record 10 of Set 9 | aklavik
# Processing Record 11 of Set 9 | bogande
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | saurimo
# Processing Record 14 of Set 9 | cockburn town
# Processing Record 15 of Set 9 | zhangye
# Processing Record 16 of Set 9 | okhotsk
# Processing Record 17 of Set 9 | gat
# Processing Record 18 of Set 9 | egvekinot
# Processing Record 19 of Set 9 | yanam
# Processing Record 20 of Set 9 | van
# Processing Record 21 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 9 | guanay
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | qaqortoq
# Processing Record 25 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 9 | marck
# Processing Record 27 of Set 9 | dong xoai
# Processing Record 28 of Set 9 | dhadar
# Processing Record 29 of Set 9 | pingliang
# Processing Record 30 of Set 9 | boffa
# Processing Record 31 of Set 9 | luanda
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | negombo
# Processing Record 34 of Set 9 | santiago
# Processing Record 35 of Set 9 | dakoro
# Processing Record 36 of Set 9 | andenes
# Processing Record 37 of Set 9 | qandala
# Processing Record 38 of Set 9 | namatanai
# Processing Record 39 of Set 9 | kodiak
# Processing Record 40 of Set 9 | lompoc
# Processing Record 41 of Set 9 | miquelon
# Processing Record 42 of Set 9 | weligama
# Processing Record 43 of Set 9 | sisimiut
# Processing Record 44 of Set 9 | srandakan
# Processing Record 45 of Set 9 | pudozh
# Processing Record 46 of Set 9 | corn island
# Processing Record 47 of Set 9 | lovozero
# Processing Record 48 of Set 9 | caramay
# Processing Record 49 of Set 9 | dutlwe
# Processing Record 50 of Set 9 | riyadh
# Processing Record 1 of Set 10 | nuevo progreso
# Processing Record 2 of Set 10 | strezhevoy
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | esil
# Processing Record 5 of Set 10 | tura
# Processing Record 6 of Set 10 | salalah
# Processing Record 7 of Set 10 | lodwar
# Processing Record 8 of Set 10 | berdigestyakh
# Processing Record 9 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 10 | lala
# Processing Record 11 of Set 10 | labrea
# Processing Record 12 of Set 10 | halifax
# Processing Record 13 of Set 10 | yinchuan
# Processing Record 14 of Set 10 | oranjemund
# Processing Record 15 of Set 10 | aberdeen
# Processing Record 16 of Set 10 | henties bay
# Processing Record 17 of Set 10 | port hedland
# Processing Record 18 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 10 | kushima
# Processing Record 20 of Set 10 | kerman
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | ust-nera
# Processing Record 23 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 24 of Set 10 | walvis bay
# Processing Record 25 of Set 10 | tiznit
# Processing Record 26 of Set 10 | mizdah
# Processing Record 27 of Set 10 | erenhot
# Processing Record 28 of Set 10 | abadan
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | aykhal
# Processing Record 31 of Set 10 | limpapa
# Processing Record 32 of Set 10 | conde
# Processing Record 33 of Set 10 | naantali
# Processing Record 34 of Set 10 | mocuba
# Processing Record 35 of Set 10 | lokosovo
# Processing Record 36 of Set 10 | lexington
# Processing Record 37 of Set 10 | mount gambier
# Processing Record 38 of Set 10 | hualmay
# Processing Record 39 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 10 | sola
# Processing Record 41 of Set 10 | baoro
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | yerbogachen
# Processing Record 44 of Set 10 | westport
# Processing Record 45 of Set 10 | beidao
# Processing Record 46 of Set 10 | de-kastri
# Processing Record 47 of Set 10 | saint-marc
# Processing Record 48 of Set 10 | shelbyville
# Processing Record 49 of Set 10 | mukdahan
# Processing Record 50 of Set 10 | bongandanga
# Processing Record 1 of Set 11 | tevaitoa
# Processing Record 2 of Set 11 | mandera
# Processing Record 3 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 11 | nampula
# Processing Record 5 of Set 11 | katherine
# Processing Record 6 of Set 11 | pasighat
# Processing Record 7 of Set 11 | darhan
# Processing Record 8 of Set 11 | port keats
# Processing Record 9 of Set 11 | inyonga
# Processing Record 10 of Set 11 | ngunguru
# Processing Record 11 of Set 11 | shumikhinskiy
# Processing Record 12 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 13 of Set 11 | algarrobo
# Processing Record 14 of Set 11 | jining
# Processing Record 15 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 16 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | vao
# Processing Record 21 of Set 11 | cozumel
# Processing Record 22 of Set 11 | nemuro
# Processing Record 23 of Set 11 | pouebo
# Processing Record 24 of Set 11 | tezu
# Processing Record 25 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 11 | moissala
# Processing Record 27 of Set 11 | castrillon
# Processing Record 28 of Set 11 | belmonte
# Processing Record 29 of Set 11 | xiamen
# Processing Record 30 of Set 11 | ancud
# Processing Record 31 of Set 11 | samaro
# Processing Record 32 of Set 11 | nacala
# Processing Record 33 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 11 | vista hermosa
# Processing Record 35 of Set 11 | bacolod
# Processing Record 36 of Set 11 | tomatlan
# Processing Record 37 of Set 11 | kihei
# Processing Record 38 of Set 11 | tokur
# Processing Record 39 of Set 11 | necochea
# Processing Record 40 of Set 11 | barcelos
# Processing Record 41 of Set 11 | morgan city
# Processing Record 42 of Set 11 | coyoles
# Processing Record 43 of Set 11 | lamballe
# Processing Record 44 of Set 11 | plotnikovo
# Processing Record 45 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 46 of Set 11 | port hardy
# Processing Record 47 of Set 11 | jorhat
# Processing Record 48 of Set 11 | panaba
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | russell
# Processing Record 1 of Set 12 | morrope
# Processing Record 2 of Set 12 | ixtapa
# Processing Record 3 of Set 12 | kutum
# Processing Record 4 of Set 12 | port augusta
# Processing Record 5 of Set 12 | monki
# Processing Record 6 of Set 12 | loudi
# Processing Record 7 of Set 12 | polunochnoye
# Processing Record 8 of Set 12 | puerto madryn
# Processing Record 9 of Set 12 | palmer
# Processing Record 10 of Set 12 | beisfjord
# Processing Record 11 of Set 12 | alta floresta
# Processing Record 12 of Set 12 | cayenne
# Processing Record 13 of Set 12 | juegang
# Processing Record 14 of Set 12 | bathurst
# Processing Record 15 of Set 12 | coldingham
# Processing Record 16 of Set 12 | kavieng
# Processing Record 17 of Set 12 | abha
# Processing Record 18 of Set 12 | winneba
# Processing Record 19 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 12 | pecos
# Processing Record 21 of Set 12 | hokitika
# Processing Record 22 of Set 12 | troitsko-pechorsk
# Processing Record 23 of Set 12 | kamina
# Processing Record 24 of Set 12 | rafaela
# Processing Record 25 of Set 12 | stykkisholmur
# Processing Record 26 of Set 12 | sibu
# Processing Record 27 of Set 12 | mayo
# Processing Record 28 of Set 12 | macas
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | olafsvik
# Processing Record 31 of Set 12 | xiaoyi
# Processing Record 32 of Set 12 | saint pete beach
# Processing Record 33 of Set 12 | hailun
# Processing Record 34 of Set 12 | merthyr tydfil
# Processing Record 35 of Set 12 | pastos bons
# Processing Record 36 of Set 12 | high level
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | waingapu
# Processing Record 39 of Set 12 | gaogou
# Processing Record 40 of Set 12 | klaksvik
# Processing Record 41 of Set 12 | erzin
# Processing Record 42 of Set 12 | nantucket
# Processing Record 43 of Set 12 | awjilah
# Processing Record 44 of Set 12 | dukat
# Processing Record 45 of Set 12 | mola di bari
# Processing Record 46 of Set 12 | mounana
# Processing Record 47 of Set 12 | khanpur
# Processing Record 48 of Set 12 | san javier
# Processing Record 49 of Set 12 | hamadan
# Processing Record 50 of Set 12 | beringovskiy
# Processing Record 1 of Set 13 | eureka
# Processing Record 2 of Set 13 | el tigre
# Processing Record 3 of Set 13 | opuwo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Mindelo      CV  16.8901  -24.9804     70.54        74
# 1                      Poum      NC -20.2333  164.0167     81.91        84
# 2                     Pisco      PE -13.7000  -76.2167     66.25        82
# 3                   Mataura      NZ -46.1927  168.8643     65.12        50
# 4                  Harqalah      TN  36.0303   10.5090     57.06        71
# 5                     Sitka      US  57.0531 -135.3300     42.69        65
# 6                Nikolskoye      RU  59.7035   30.7861     28.80        94
# 7                   Rikitea      PF -23.1203 -134.9692     77.43        65
# 8  Sao Jose Da Coroa Grande      BR  -8.8978  -35.1478     78.28        83
# 9         Sao Joao Da Barra      BR -21.6403  -41.0511     74.64        92
#
#    Cloudiness  Wind Speed Current Description
# 0           8        7.45           clear sky
# 1         100       20.02       moderate rain
# 2           0       14.97           clear sky
# 3           5        0.74           clear sky
# 4          40        9.22    scattered clouds
# 5          75        8.05       broken clouds
# 6          66        3.74       broken clouds
# 7         100        9.60     overcast clouds
# 8          49        8.72    scattered clouds
# 9           0        6.58           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
